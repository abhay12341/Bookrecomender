# %%
import pandas as pd
df1 = pd.read_csv("C:\\Users\\Gyanendra\\Desktop\\files\\book.csv")
df2 = pd.read_csv("C:\\Users\\Gyanendra\\Desktop\\files\\book_new.csv")
df1.shape
# Out:
# (211, 5)

# %%
df1.head()
# Out:
#                       Title            Author              Genre  Height  \
# 0  Fundamentals of Wavelets  Goswami, Jaideva  signal_processing     228
# 1                Data Smart     Foreman, John       data_science     235
# 2  God Created the Integers  Hawking, Stephen        mathematics     197
# 3         Superfreakonomics   Dubner, Stephen          economics     179
# 4               Orientalism      Said, Edward            history     197
#
#        Publisher
# 0          Wiley
# 1          Wiley
# 2        Penguin
# 3  HarperCollins
# 4        Penguin

# %%
df2.head()
# Out:
#                       Title            Author       Genre           SubGenre  \
# 0  Fundamentals of Wavelets  Goswami, Jaideva        tech  signal_processing
# 1                Data Smart     Foreman, John        tech       data_science
# 2  God Created the Integers  Hawking, Stephen        tech        mathematics
# 3         Superfreakonomics   Dubner, Stephen     science          economics
# 4               Orientalism      Said, Edward  nonfiction            history
#
#    Height      Publisher
# 0     228          Wiley
# 1     235          Wiley
# 2     197        Penguin
# 3     179  HarperCollins
# 4     197        Penguin

# %%
df1.isna()
# Out:
#      Title  Author  Genre  Height  Publisher
# 0    False   False  False   False      False
# 1    False   False  False   False      False
# 2    False   False  False   False      False
# 3    False   False  False   False      False
# 4    False   False  False   False      False
# ..     ...     ...    ...     ...        ...
# 206  False   False  False   False       True
# 207  False   False  False   False       True
# 208  False   False  False   False       True
# 209  False   False  False   False       True
# 210  False   False  False   False       True
#
# [211 rows x 5 columns]

# %%
for cols in df1:
    print(f"{cols} : {df1[cols].unique()}")
# Out:
# Title : ['Fundamentals of Wavelets' 'Data Smart' 'God Created the Integers'
#  'Superfreakonomics' 'Orientalism'
#  'Nature of Statistical Learning Theory, The'
#  'Integration of the Indian States' "Drunkard's Walk, The"
#  'Image Processing & Mathematical Morphology'
#  'How to Think Like Sherlock Holmes' 'Data Scientists at Work'
#  'Slaughterhouse Five' 'Birth of a Theorem'
#  'Structure & Interpretation of Computer Programs' 'Age of Wrath, The'
#  'Trial, The' "Statistical Decision Theory'" 'Data Mining Handbook'
#  'New Machiavelli, The' 'Physics & Philosophy' 'Making Software'
#  'Analysis, Vol I' 'Machine Learning for Hackers'
#  'Signal and the Noise, The' 'Python for Data Analysis'
#  'Introduction to Algorithms' 'Beautiful and the Damned, The'
#  'Outsider, The' 'Complete Sherlock Holmes, The - Vol I'
#  'Complete Sherlock Holmes, The - Vol II' 'Wealth of Nations, The'
#  'Pillars of the Earth, The' 'Mein Kampf' 'Tao of Physics, The'
# ...

# %%
df1['Genre'].unique()
# Out:
# array(['signal_processing', 'data_science', 'mathematics', 'economics',
#        'history', 'science', 'psychology', 'fiction', 'computer_science',
#        'nonfiction', 'philosophy', 'comic'], dtype=object)

# %%
df1.Height.unique().shape
# Out:
# (65,)

# %%
df1.Height.notna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 206    True
# 207    True
# 208    True
# 209    True
# 210    True
# Name: Height, Length: 211, dtype: bool

# %%
df1.Publisher.unique().shape
# Out:
# (34,)

# %%
df1['Publisher'].isnull().values.any()
# Out:
# True

# %%
df1.isnull().values.any()
# Out:
# True

# %%
for cols in df1:
    print(f'{cols} : {df1[cols].isnull().values.any()}')
# Out:
# Title : False
# Author : True
# Genre : False
# Height : False
# Publisher : True

# %%
for cols in df2:
    print(f"{cols} : {df2[cols].isnull().values.any()}")
# Out:
# Title : False
# Author : True
# Genre : False
# SubGenre : False
# Height : False
# Publisher : True

# %%
df2.shape
# Out:
# (211, 6)

# %%
df1 = df1.drop(['Author','Publisher'],axis = 'columns')
df1
# Out:
#                             Title              Genre  Height
# 0        Fundamentals of Wavelets  signal_processing     228
# 1                      Data Smart       data_science     235
# 2        God Created the Integers        mathematics     197
# 3               Superfreakonomics          economics     179
# 4                     Orientalism            history     197
# ..                            ...                ...     ...
# 206      Structure and Randomness        mathematics     252
# 207  Image Processing with MATLAB  signal_processing     241
# 208                   Animal Farm            fiction     180
# 209                    Idiot, The            fiction     197
# 210            Christmas Carol, A            fiction     196
#
# [211 rows x 3 columns]

# %%
df1
# Out:
#                             Title              Genre  Height
# 0        Fundamentals of Wavelets  signal_processing     228
# 1                      Data Smart       data_science     235
# 2        God Created the Integers        mathematics     197
# 3               Superfreakonomics          economics     179
# 4                     Orientalism            history     197
# ..                            ...                ...     ...
# 206      Structure and Randomness        mathematics     252
# 207  Image Processing with MATLAB  signal_processing     241
# 208                   Animal Farm            fiction     180
# 209                    Idiot, The            fiction     197
# 210            Christmas Carol, A            fiction     196
#
# [211 rows x 3 columns]

# %%
df1
# Out:
#                             Title              Genre  Height
# 0        Fundamentals of Wavelets  signal_processing     228
# 1                      Data Smart       data_science     235
# 2        God Created the Integers        mathematics     197
# 3               Superfreakonomics          economics     179
# 4                     Orientalism            history     197
# ..                            ...                ...     ...
# 206      Structure and Randomness        mathematics     252
# 207  Image Processing with MATLAB  signal_processing     241
# 208                   Animal Farm            fiction     180
# 209                    Idiot, The            fiction     197
# 210            Christmas Carol, A            fiction     196
#
# [211 rows x 3 columns]

# %%
df1['Genre'].unique()
# Out:
# array(['signal_processing', 'data_science', 'mathematics', 'economics',
#        'history', 'science', 'psychology', 'fiction', 'computer_science',
#        'nonfiction', 'philosophy', 'comic'], dtype=object)

# %%
for cols in df1['Genre'].unique():
    print(df1['Title'])
# Out:
# 0          Fundamentals of Wavelets
# 1                        Data Smart
# 2          God Created the Integers
# 3                 Superfreakonomics
# 4                       Orientalism
#                    ...
# 206        Structure and Randomness
# 207    Image Processing with MATLAB
# 208                     Animal Farm
# 209                      Idiot, The
# 210              Christmas Carol, A
# Name: Title, Length: 211, dtype: object
# 0          Fundamentals of Wavelets
# 1                        Data Smart
# 2          God Created the Integers
# 3                 Superfreakonomics
# 4                       Orientalism
#                    ...
# 206        Structure and Randomness
# 207    Image Processing with MATLAB
# 208                     Animal Farm
# 209                      Idiot, The
# 210              Christmas Carol, A
# Name: Title, Length: 211, dtype: object
# 0          Fundamentals of Wavelets
# 1                        Data Smart
# ...

# %%
df1
# Out:
#                             Title              Genre  Height
# 0        Fundamentals of Wavelets  signal_processing     228
# 1                      Data Smart       data_science     235
# 2        God Created the Integers        mathematics     197
# 3               Superfreakonomics          economics     179
# 4                     Orientalism            history     197
# ..                            ...                ...     ...
# 206      Structure and Randomness        mathematics     252
# 207  Image Processing with MATLAB  signal_processing     241
# 208                   Animal Farm            fiction     180
# 209                    Idiot, The            fiction     197
# 210            Christmas Carol, A            fiction     196
#
# [211 rows x 3 columns]

# %%
import numpy as np
dff = df1.groupby(['Genre','Title']).sum()

# %%
dff
# Out:
#                                                               Height
# Genre             Title
# comic             Batman Earth One                               265
#                   Batman Handbook                                270
#                   Batman: The Long Halloween                     258
#                   Crisis on Infinite Earths                      258
#                   Death of Superman, The                         258
# ...                                                              ...
# science           Tao of Physics, The                            179
#                   Theory of Everything, The                      217
# signal_processing Fundamentals of Wavelets                       228
#                   Image Processing & Mathematical Morphology     241
#                   Image Processing with MATLAB                   241
#
# [210 rows x 1 columns]

# %%
dff.head(60)
# Out:
#                                                                   Height
# Genre            Title
# comic            Batman Earth One                                    265
#                  Batman Handbook                                     270
#                  Batman: The Long Halloween                          258
#                  Crisis on Infinite Earths                           258
#                  Death of Superman, The                              258
#                  Final Crisis                                        257
#                  Flashpoint                                          265
#                  History of the DC Universe                          258
#                  Justice League: The Villain's Journey               258
#                  Justice League: Throne of Atlantis                  258
#                  Killing Joke, The                                   283
#                  Superman Earth One - 1                              259
# ...

# %%
dff.Height['signal_processing']
# Out:
# Title
# Fundamentals of Wavelets                      228
# Image Processing & Mathematical Morphology    241
# Image Processing with MATLAB                  241
# Name: Height, dtype: int64

# %%
df1['Genre'].unique()
# Out:
# array(['signal_processing', 'data_science', 'mathematics', 'economics',
#        'history', 'science', 'psychology', 'fiction', 'computer_science',
#        'nonfiction', 'philosophy', 'comic'], dtype=object)

# %%
def recommender_algo(genre):
    dff = df1.groupby(['Genre','Title']).sum()
    return dff.Height[genre]

# %%
recommender_algo(['comic'])
# Out:
# Genre  Title
# comic  Batman Earth One                         265
#        Batman Handbook                          270
#        Batman: The Long Halloween               258
#        Crisis on Infinite Earths                258
#        Death of Superman, The                   258
#        Final Crisis                             257
#        Flashpoint                               265
#        History of the DC Universe               258
#        Justice League: The Villain's Journey    258
#        Justice League: Throne of Atlantis       258
#        Killing Joke, The                        283
#        Superman Earth One - 1                   259
#        Superman Earth One - 2                   258
# Name: Height, dtype: int64

# %%
recommender_algo(['philosophy'])
# Out:
# Genre       Title
# philosophy  Arthashastra, The                          214
#             Ayn Rand Answers                           203
#             Free Will                                  203
#             History of Western Philosophy              213
#             Identity & Violence                        219
#             Justice, Judiciary and Democracy           224
#             On Education                               203
#             Philosophy: Who Needs It                   171
#             Political Philosophers                     162
#             Prince, The                                173
#             Return of the Primitive                    202
#             Story of Philosophy, The                   170
#             Unpopular Essays                           198
#             We the Nation                              216
#             We the People                              216
#             World's Great Thinkers, The                189
# ...

# %%
import pickle

# %%
with open('Recommender_algo','wb') as f:
    pickle.dump(recommender_algo,f)

# %%
with open('Recommender_algo','rb') as f:
    model = pickle.load(f)

# %%
model(['philosophy'])
# Out:
# Genre       Title
# philosophy  Arthashastra, The                          214
#             Ayn Rand Answers                           203
#             Free Will                                  203
#             History of Western Philosophy              213
#             Identity & Violence                        219
#             Justice, Judiciary and Democracy           224
#             On Education                               203
#             Philosophy: Who Needs It                   171
#             Political Philosophers                     162
#             Prince, The                                173
#             Return of the Primitive                    202
#             Story of Philosophy, The                   170
#             Unpopular Essays                           198
#             We the Nation                              216
#             We the People                              216
#             World's Great Thinkers, The                189
# ...

# %%
model(['science'])
# Out:
# Genre    Title
# science  Artist and the Mathematician, The        186
#          Broca's Brain                            174
#          Code Book, The                           197
#          Drunkard's Walk, The                     197
#          Electric Universe                        201
#          Hidden Connections, The                  197
#          Information, The                         233
#          Numbers Behind Numb3rs, The              202
#          Oxford book of Modern Science Writing    240
#          Physics & Philosophy                     197
#          Simpsons & Their Mathematical Secrets    233
#          Surely You're Joking Mr Feynman          198
#          Tao of Physics, The                      179
#          Theory of Everything, The                217
# Name: Height, dtype: int64

# %%
df1['Genre'].unique()
# Out:
# array(['signal_processing', 'data_science', 'mathematics', 'economics',
#        'history', 'science', 'psychology', 'fiction', 'computer_science',
#        'nonfiction', 'philosophy', 'comic'], dtype=object)

# %%
model(['economics'])
# Out:
# Genre      Title
# economics  Age of Discontuinity, The                178
#            Econometric Analysis                     242
#            Freakonomics                             197
#            Journal of Economics, vol 106 No 3       235
#            New Markets & Other Essays               176
#            Rationality & Freedom                    213
#            Social Choice & Welfare, Vol 39 No. 1    235
#            Superfreakonomics                        179
#            Textbook of Economic Theory              242
#            Wealth of Nations, The                   175
# Name: Height, dtype: int64
